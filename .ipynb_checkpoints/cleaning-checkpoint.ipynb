# %%
import pandas as pd
import numpy as np

# %%
df_csv = pd.read_csv("prop_details.csv")

# %%
df_csv
# Out:
#        Unnamed: 0             prop_size  \
# 0               0  1,695 to 4,645 Sq Ft
# 1               1  1,695 to 4,645 Sq Ft
# 2               2           5,690 Sq Ft
# 3               3  1,695 to 4,645 Sq Ft
# 4               4           5,690 Sq Ft
# ...           ...                   ...
# 15078       15078           2,407 Sq Ft
# 15079       15079             354 Sq Ft
# 15080       15080          11,763 Sq Ft
# 15081       15081             824 Sq Ft
# 15082       15082           2,226 Sq Ft
#
#                                                prop_desc       prop_price
# 0      Office / Residential Opportunity, 40 Great Smi...  - £3,400,000.00
# 1      Office / Residential Opportunity, 40 Great Smi...  - £3,400,000.00
# 2      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...  - £2,250,000.00
# 3      Office / Residential Opportunity, 40 Great Smi...  - £3,400,000.00
# 4      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...  - £2,250,000.00
# ...

# %%
df_preclean = df_csv[['prop_size','prop_desc','prop_price']].copy()

# %%
df_preclean['prop_price'] = df_preclean['prop_price'].str.replace('- £','')

# %%
df_preclean
# Out:
#                   prop_size  \
# 0      1,695 to 4,645 Sq Ft
# 1      1,695 to 4,645 Sq Ft
# 2               5,690 Sq Ft
# 3      1,695 to 4,645 Sq Ft
# 4               5,690 Sq Ft
# ...                     ...
# 15078           2,407 Sq Ft
# 15079             354 Sq Ft
# 15080          11,763 Sq Ft
# 15081             824 Sq Ft
# 15082           2,226 Sq Ft
#
#                                                prop_desc    prop_price
# 0      Office / Residential Opportunity, 40 Great Smi...  3,400,000.00
# 1      Office / Residential Opportunity, 40 Great Smi...  3,400,000.00
# 2      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...  2,250,000.00
# 3      Office / Residential Opportunity, 40 Great Smi...  3,400,000.00
# 4      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...  2,250,000.00
# ...                                                  ...           ...
# 15078  Long Leasehold Warehouse For Sale, Unit 4C Red...    355,000.00
# ...

# %%
df_preclean['prop_price'] = df_preclean['prop_price'].str.replace(',','')

# %%
df_preclean
# Out:
#                   prop_size  \
# 0      1,695 to 4,645 Sq Ft
# 1      1,695 to 4,645 Sq Ft
# 2               5,690 Sq Ft
# 3      1,695 to 4,645 Sq Ft
# 4               5,690 Sq Ft
# ...                     ...
# 15078           2,407 Sq Ft
# 15079             354 Sq Ft
# 15080          11,763 Sq Ft
# 15081             824 Sq Ft
# 15082           2,226 Sq Ft
#
#                                                prop_desc  prop_price
# 0      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 1      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 2      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...   2250000.0
# 3      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 4      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...   2250000.0
# ...                                                  ...         ...
# 15078  Long Leasehold Warehouse For Sale, Unit 4C Red...    355000.0
# ...

# %%
df_preclean['prop_size'] = df_preclean['prop_size'].str.replace('Sq Ft','')

# %%
df_preclean
# Out:
#              prop_size                                          prop_desc  \
# 0      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 1      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 2               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# 3      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 4               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# ...                ...                                                ...
# 15078           2,407   Long Leasehold Warehouse For Sale, Unit 4C Red...
# 15079             354   3 Burywood Court, 147 Hertford Road, Enfield, ...
# 15080          11,763   Units 1-3 Redburn Industrial Estate, Woodall R...
# 15081             824                 200, Green Street, Enfield, EN3 7NG
# 15082           2,226           38a, Holmethorpe Avenue, Redhill, RH1 2NL
#
#        prop_price
# 0       3400000.0
# 1       3400000.0
# 2       2250000.0
# ...

# %%
df_preclean = df_preclean.rename(columns={"prop_size": "prop_size(Sq Ft)"})

# %%
df_preclean
# Out:
#       prop_size(Sq Ft)                                          prop_desc  \
# 0      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 1      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 2               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# 3      1,695 to 4,645   Office / Residential Opportunity, 40 Great Smi...
# 4               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# ...                ...                                                ...
# 15078           2,407   Long Leasehold Warehouse For Sale, Unit 4C Red...
# 15079             354   3 Burywood Court, 147 Hertford Road, Enfield, ...
# 15080          11,763   Units 1-3 Redburn Industrial Estate, Woodall R...
# 15081             824                 200, Green Street, Enfield, EN3 7NG
# 15082           2,226           38a, Holmethorpe Avenue, Redhill, RH1 2NL
#
#        prop_price
# 0       3400000.0
# 1       3400000.0
# 2       2250000.0
# ...

# %%
# Splitting the size column into lower and upper limit
new_preclean = df_preclean["prop_size(Sq Ft)"].str.split("to", n = 1, expand = True)

# %%
# making separate lower limit from new data frame 
df_preclean["prop_size(lower) SQ Ft"]= new_preclean[0]

# %%
# making separate lower limit from new data frame 
df_preclean["prop_size(upper) SQ Ft"]= new_preclean[1]

# %%
df_preclean
# Out:
#       prop_size(Sq Ft)                                          prop_desc  \
# 0               1,695   Office / Residential Opportunity, 40 Great Smi...
# 1               1,695   Office / Residential Opportunity, 40 Great Smi...
# 2               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# 3               1,695   Office / Residential Opportunity, 40 Great Smi...
# 4               5,690   B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...
# ...                ...                                                ...
# 15078           2,407   Long Leasehold Warehouse For Sale, Unit 4C Red...
# 15079             354   3 Burywood Court, 147 Hertford Road, Enfield, ...
# 15080          11,763   Units 1-3 Redburn Industrial Estate, Woodall R...
# 15081             824                 200, Green Street, Enfield, EN3 7NG
# 15082           2,226           38a, Holmethorpe Avenue, Redhill, RH1 2NL
#
#        prop_price prop_size(lower) SQ Ft prop_size(upper) SQ Ft
# ...

# %%
df_preclean.drop(columns='prop_size(Sq Ft)',inplace=True)

# %%
df_preclean
# Out:
#                                                prop_desc  prop_price  \
# 0      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 1      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 2      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...   2250000.0
# 3      Office / Residential Opportunity, 40 Great Smi...   3400000.0
# 4      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...   2250000.0
# ...                                                  ...         ...
# 15078  Long Leasehold Warehouse For Sale, Unit 4C Red...    355000.0
# 15079  3 Burywood Court, 147 Hertford Road, Enfield, ...         NaN
# 15080  Units 1-3 Redburn Industrial Estate, Woodall R...         NaN
# 15081                200, Green Street, Enfield, EN3 7NG    400000.0
# 15082          38a, Holmethorpe Avenue, Redhill, RH1 2NL         NaN
#
#       prop_size(lower) SQ Ft prop_size(upper) SQ Ft
# 0                     1,695                  4,645
# ...

# %%
df_preclean = df_preclean.rename(columns={"prop_price": "prop_price(£)"})

# %%
df_preclean
# Out:
#                                                prop_desc  prop_price(£)  \
# 0      Office / Residential Opportunity, 40 Great Smi...      3400000.0
# 1      Office / Residential Opportunity, 40 Great Smi...      3400000.0
# 2      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...      2250000.0
# 3      Office / Residential Opportunity, 40 Great Smi...      3400000.0
# 4      B1 Unit or May Suit A1, A2, D1, D2 (STP), Pala...      2250000.0
# ...                                                  ...            ...
# 15078  Long Leasehold Warehouse For Sale, Unit 4C Red...       355000.0
# 15079  3 Burywood Court, 147 Hertford Road, Enfield, ...            NaN
# 15080  Units 1-3 Redburn Industrial Estate, Woodall R...            NaN
# 15081                200, Green Street, Enfield, EN3 7NG       400000.0
# 15082          38a, Holmethorpe Avenue, Redhill, RH1 2NL            NaN
#
#       prop_size(lower) SQ Ft prop_size(upper) SQ Ft
# 0                     1,695                  4,645
# ...
